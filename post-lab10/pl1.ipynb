# %%
import matplotlib.pyplot as plt

# Step 1: Data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Step 2: Plot line
plt.plot(x, y)

# Step 3: Add labels and title
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Simple Line Graph")

# Step 4: Show graph
plt.show()
